# %% [markdown]
# ## Pratice
# Fig. 3 from Licciardi et al. (2022) Instantaneous tracking of earthquake growth with elastogravity signals
#
# 1. 使用檔案 `41586_2022_4672_MOESM4_ESM.csv`
# 2. 盡量畫出一樣的圖，或是比這張更漂亮的圖
# 3. 你可能會用到以下指令
#     1. df=pd.read_csv(...)
#     2. df.keys()
#     3. plt.subplots(21?)
#
#     4. plt.plot()

# %% [markdown]
# ![image.png](attachment:31f0b311-b594-49fe-a0d2-ad8ab555094e.png)
