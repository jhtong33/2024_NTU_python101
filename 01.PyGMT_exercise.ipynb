# %%
import pygmt

# %% [markdown]
# Lin et al. (2020)
# ![image.png](attachment:a65ba835-37be-4ae8-b54a-c99b392cd096.png)

# %% [markdown]
# ## Exercise 1
# 請以臺灣TATO測站（24.9754°N, 121.4881°E, Elevation: 53.0 m）為中心:
# 1. 以方位投影方式，畫出0°–60°的範圍
# 2. 使用`PB2002_boundaries.dig.txt`畫出板塊邊界
# 3. 使用`pandas`讀取地震檔案 `Events_nearTaiwan_2023.csv`
# 4. 使用`pygmt.makecpt`，畫出地震深度隨顏色的變化
# 5. 依照地震規模變化圓圈大小
# 6. 使用`figure.colorbar`畫出colorbar
# 7. 儲存圖片檔案

# %%
# your code

# %% [markdown]
# ## Exercise 2
# 使用`figure.histogram`和地震檔案 `Events_nearTaiwan_2023.csv`畫出[範例圖](https://www.pygmt.org/dev/gallery/histograms/histogram.html#sphx-glr-gallery-histograms-histogram-py)，並且增加2–3個自己的元素！（不要copy paste！）

# %%
# your code
